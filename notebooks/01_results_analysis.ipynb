# %% [markdown]
# # MySQL E-commerce Analytics Results
# This notebook displays exported SQL results. It intentionally does not reimplement business logic in pandas.

# %%
from pathlib import Path
import pandas as pd
TABLES = Path('../reports/tables')
monthly = pd.read_csv(TABLES / 'monthly_kpis.csv')
monthly
